# %%
--------------------------------INFORME VISUALIZACIÓN EXPLORATORIA------------------------

-------- Conjunto de Datos -----------

Los datos han sido obtenidos de la base de datos Nacionalism & Corruption con acceso public en 
https://www.kaggle.com/datasets/joebeachcapital/nationalism-and-corruption/data 

La base de datos presenta una tabla nat_and_corruption y los datos estan almaxenados en un archivo tipo .csv. Esta compuesta por 30 columnas que son las mostradas a continuación:

 #   Column                                                      Non-Null Count  Dtype  
---  ------                                                      --------------  -----  
 0   iso3c                                                       18628 non-null  object 
 1   year                                                        18628 non-null  int64  
 2   country_name                                                18628 non-null  object 
 3   v2exl_legitideol                                            18293 non-null  float64
 4   v2exl_legitideolcr_0                                        18506 non-null  float64
 5   v2exl_legitideolcr_1                                        18506 non-null  float64
 6   v2exl_legitideolcr_2                                        18506 non-null  float64
 7   v2exl_legitideolcr_3                                        18506 non-null  float64
 8   v2exl_legitideolcr_4                                        18506 non-null  float64
 9   top_ideology                                                18506 non-null  object 
 10  nationalism                                                 17551 non-null  float64
 11  country                                                     10211 non-null  object 
 12  iso2c                                                       10148 non-null  object 
 13  wdi_prop_less_2_usd_day                                     1926 non-null   float64
 14  wdi_gdppc_nominal                                           8963 non-null   float64
 15  wdi_gdppc_ppp                                               5354 non-null   float64
 16  wdi_urban_population_pct                                    10211 non-null  float64
 17  wdi_urban_pop_1m_cities_pct                                 7327 non-null   float64
 18  wdi_gini_index                                              1911 non-null   float64
 19  wdi_life_expectancy_at_birth                                9803 non-null   float64
 20  wdi_pop_over_65                                             10211 non-null  float64
 21  wdi_pop_under_15                                            10211 non-null  float64
 22  wdi_population                                              10211 non-null  float64
 23  corruption                                                  1884 non-null   float64
 24  regime_use_of_ideology_measure                              18293 non-null  float64
 25  ideology_is_nationalist_percent_of_experts                  18506 non-null  float64
 26  ideology_is_socialist_or_communist_percent_of_experts       18506 non-null  float64
 27  ideology_is_restorative_or_conservative_percent_of_experts  18506 non-null  float64
 28  ideology_is_separatist_or_autonomist_percent_of_experts     18506 non-null  float64
 29  ideology_is_religious_percent_of_experts                    18506 non-null  float64


Identificadores y Metadatos

iso3c: Código de tres letras que identifica al país según el estándar ISO 3166-1 alfa-3. Ejemplo: USA para Estados Unidos.
iso2c: Código de dos letras que identifica al país según el estándar ISO 3166-1 alfa-2. Ejemplo: US para Estados Unidos.
country_name: Nombre del país en texto completo.
country: Campo adicional que probablemente duplique o modifique country_name con algún formato diferente.
year: Año al que corresponden los datos de la fila.

Indicadores de Ideología y Nacionalismo

v2exl_legitideol: Medida general de la legitimidad ideológica percibida por el régimen en el poder. Este valor puede ser una media ponderada calculada con base en encuestas o análisis de expertos.
v2exl_legitideolcr_0 al v2exl_legitideolcr_4: Subdimensiones de la legitimidad ideológica, desglosadas en categorías específicas, como confianza en instituciones o ideologías predominantes.
top_ideology: Ideología predominante en el país durante el año especificado. Ejemplo: "Nacionalismo", "Socialismo".
nationalism: Medida cuantitativa del nivel de nacionalismo en el país, basada en encuestas o análisis de expertos.

Indicadores Económicos y Sociales

wdi_prop_less_2_usd_day: Proporción de la población que vive con menos de $2 USD al día, un indicador de pobreza extrema.
wdi_gdppc_nominal: PIB per cápita en dólares nominales (sin ajustes por inflación o paridad de poder adquisitivo).
wdi_gdppc_ppp: PIB per cápita ajustado por paridad de poder adquisitivo (PPP), lo que permite comparar el poder adquisitivo entre países.
wdi_urban_population_pct: Porcentaje de la población que vive en áreas urbanas.
wdi_urban_pop_1m_cities_pct: Porcentaje de la población urbana que vive en ciudades con más de 1 millón de habitantes.
wdi_gini_index: Índice de Gini, que mide la desigualdad de ingresos en una escala de 0 (igualdad perfecta) a 100 (desigualdad perfecta).
wdi_life_expectancy_at_birth: Esperanza de vida promedio al nacer, medida en años.
wdi_pop_over_65: Porcentaje de la población mayor de 65 años.
wdi_pop_under_15: Porcentaje de la población menor de 15 años.
wdi_population: Población total del país.

Indicadores de Corrupción y Uso de Ideología

corruption: Medida cuantitativa de la percepción de corrupción en el país. Puede basarse en encuestas o índices internacionales como el CPI (Índice de Percepción de la Corrupción).
regime_use_of_ideology_measure: Indicador que mide el grado en que el régimen utiliza ideologías para legitimarse o mantenerse en el poder.
ideology_is_nationalist_percent_of_experts: Porcentaje de expertos que identifican la ideología del régimen como nacionalista.
ideology_is_socialist_or_communist_percent_of_experts: Porcentaje de expertos que identifican la ideología del régimen como socialista o comunista.
ideology_is_restorative_or_conservative_percent_of_experts: Porcentaje de expertos que identifican la ideología del régimen como conservadora o restauradora.
ideology_is_separatist_or_autonomist_percent_of_experts: Porcentaje de expertos que identifican la ideología del régimen como separatista o autonomista.
ideology_is_religious_percent_of_experts: Porcentaje de expertos que identifican la ideología del régimen como religiosa.

# %%
--------- Hipótesis de Trabajo --------

1 Hipótesis relacionadas con una variable:

- El nacionalismo está experimentando un auge en el contexto actual.
- Los países con una mayor proporción de población menor de 15 años se encuentran principalmente en África.
- Los países con las mayores poblaciones totales se concentran en Asia.

2 Hipótesis relacionadas con dos variables:

- Los países con un mayor índice de nacionalismo tienden a ser aquellos en los que el régimen utiliza la ideología como herramienta para mantenerse en el poder.    
- Los países con una mayor proporción de población menor de 15 años presentan una esperanza de vida más baja.
- El aumento de la urbanización ha contribuido a un incremento en la esperanza de vida.

# %%
--------- Análisis Visual de las Hipotesisi--------

Hipótesis 1: El nacionalismo está experimentando un auge en el contexto actual.

En la gráfica Nationalism Evolution, que representa la evolución del índice de nacionalismo entre 1900 y 2020 (eje X: tiempo, eje Y: porcentaje del índice), se observa un incremento notable en los valores entre los años 2000 y 2020, lo que apoya la idea de un auge reciente de esta ideología. Sin embargo, al analizar periodos anteriores, específicamente entre 1990 y 2000, los valores del índice fueron aún más altos que los actuales. Esto indica que, aunque existe una ligera disminución respecto a ese pico, los niveles actuales siguen siendo significativamente mayores en comparación con el resto de la historia.

En la gráfica Ranking of Top Ideologies, que clasifica las ideologías predominantes por número de países (eje X: número de países, eje Y: ideologías), se observa que en 2022 el nacionalismo es la ideología predominante a nivel mundial, superando a otras corrientes ideológicas.

En conjunto, estas gráficas muestran que, aunque el nacionalismo tuvo un punto máximo entre 1990 y 2000, en el periodo 2000-2020 sigue siendo relevante y ha resurgido como una de las principales fuerzas ideológicas en la actualidad. Además, su predominancia en 2022 refuerza la idea de su auge en el contexto global.

Un factor que podría estar influyendo en este resurgimiento del nacionalismo es la digitalización y la proliferación de fake news. Aunque no fue posible comprobarlo debido a la falta de datos en la base utilizada, es plausible que el acceso rápido a la información a través de las redes sociales y la difusión de noticias falsas puedan haber amplificado sentimientos nacionalistas, contribuyendo a su auge en la última década.

# %%
Hipótesis 2: - Los países con una mayor proporción de población menor de 15 años se encuentran principalmente en África.


En la gráfica Top 5 Countries by Population Under 15 in 2022, se destacan los cinco países con el mayor porcentaje de población menor de 15 años: Nigeria, República Centroafricana, Chad, Mali y Somalia. En el eje X se muestran los datos del porcentaje de población total menor de 15 años, mientras que en el eje Y se ubican estos países según su proporción. Los valores oscilan entre el 48.75% y el 47.25%, reflejando un alto predominio de población joven en estos países.

Estos datos demográficos confirman que África concentra la mayor proporción de población menor de 15 años a nivel mundial, un fenómeno impulsado por altas tasas de natalidad y un crecimiento poblacional acelerado, particularmente en los países subsaharianos. Este patrón está relacionado con factores como sistemas de salud en desarrollo, estructuras sociales que valoran familias numerosas, y desafíos en la implementación de políticas de planificación familiar.

Un factor adicional que podría influir en este fenómeno, aunque no se tiene acceso a datos específicos en la base utilizada, es la falta de acceso a anticonceptivos en estas regiones. La escasa disponibilidad de métodos anticonceptivos podría contribuir a las altas tasas de natalidad, perpetuando el crecimiento de la población joven en estos países.

# %%
Hipótesis 3: - Los países con las mayores poblaciones totales se concentran en Asia.

En la gráfica Countries Population in 2020, se destacan los cinco países con el mayor número de habitantes. En el eje X se muestra el número de la población total, mientras que en el eje Y se ubican los países. En la subtabla Top 5 Countries with More Population in 2020, figuran China, India, Estados Unidos, Indonesia y Pakistán. Es notable que China e India presentan cifras similares, alrededor de 1.4 mil millones de personas, lo que marca una gran diferencia en comparación con los otros países en la lista.

El mapa de calor Países por Población en 2022 muestra la distribución global de los países según su población. Los países que se observan en azul están principalmente concentrados en la región de Asia, lo que indica que Asia alberga a los países más poblados del mundo.

Los países con las mayores poblaciones totales se concentran principalmente en Asia, con potencias demográficas como China, India, Indonesia y Pakistán liderando las estadísticas globales. Una excepción destacada es Estados Unidos, que, a pesar de no estar ubicado en Asia, se encuentra entre los países con las mayores poblaciones del mundo.

Este fenómeno puede deberse a varios factores. En primer lugar, los países asiáticos como China e India tienen grandes territorios y economías en crecimiento, lo que ha favorecido su alta natalidad y crecimiento poblacional. Además, estos países tienen políticas que han influido en el tamaño de sus poblaciones, como la rápida urbanización y el acceso a mejores condiciones de salud, lo que ha permitido un crecimiento continuo.

En el caso de Estados Unidos, aunque no se encuentra en Asia, su alta población puede explicarse por una combinación de factores como la inmigración, un sistema de salud más avanzado, y un modelo económico que ha promovido el crecimiento poblacional.

# %%
Hipótesis 4: Los países con un mayor índice de nacionalismo tienden a ser aquellos en los que el régimen utiliza la ideología como herramienta para mantenerse en el poder.

En las gráficas Top 5 Nationalist Countries in 2022 y Top 5 Countries by Regime Use of Ideology in 2022, se observa una tendencia similar al compararlas. Los países con un índice más alto de nacionalismo también tienen un mayor uso de la ideología para mantenerse en el poder. En la primera, el eje Y muestra el índice de nacionalismo, mientras que en la segunda, el eje Y refleja el uso de la ideología para consolidar el poder, siendo el eje X común en ambas, con los países que ocupan las mismas posiciones: Cuba, Eswatini, Afganistán, Corea del Norte y Hong Kong.

Esto sugiere que los países con un mayor índice de nacionalismo son aquellos donde los gobiernos emplean esta ideología para consolidar y perpetuar su poder. Los regímenes autoritarios aprovechan el nacionalismo para movilizar a la población, reforzar su legitimidad y justificar políticas autoritarias o excluyentes. De esta manera, crean una narrativa que unifica a la nación bajo valores comunes, apelando a la identidad cultural, el patriotismo o la defensa contra amenazas externas, lo que fortalece su control político y social.

Existen varios factores que podrían explicar esta correlación. El nacionalismo se utiliza para crear un sentido de unidad en poblaciones con tensiones internas o amenazas externas. También puede distraer a la población de problemas sociales y económicos, fortaleciendo así el poder del régimen. Además, puede ser usado para promover políticas que favorezcan a grupos étnicos o religiosos específicos, excluyendo a las minorías.

Otros factores incluyen el control de los medios de comunicación y la educación, que son manipulados para difundir ideologías nacionalistas desde temprana edad, y la estrategia de crear enemigos externos, lo que fortalece el poder del líder y crea un ambiente de unidad y defensa de la nación.

# %%
Hipótesis 5: El aumento de la urbanización ha contribuido a un incremento en la esperanza de vida.

En la gráfica Population Under 15 vs. Life Expectancy by Country (Top 100), se observa que los países con una mayor proporción de personas menores de 15 años suelen tener una esperanza de vida más baja. En el eje X se muestra el porcentaje de la población menor de 15 años y la esperanza de vida en años, mientras que en el eje Y se encuentran los países. Al analizar la subtabla Population Under 15 vs. Life Expectancy by Country (Top 20), se confirma que la esperanza de vida en estos países no supera los 70 años.

Este fenómeno se puede explicar por varios factores, como las altas tasas de natalidad y el rápido crecimiento poblacional en algunas regiones, donde el acceso a servicios de salud de calidad es limitado. Además, la falta de infraestructura adecuada, la pobreza y las carencias en educación también juegan un papel negativo en la esperanza de vida, especialmente en países con una gran proporción de población joven. Sin embargo, la urbanización podría ser un factor positivo en otros contextos, ya que mejora el acceso a servicios de salud, infraestructura y mejores condiciones de vida, lo que podría contribuir a un aumento en la esperanza de vida.

# %%
Hipótesis 6: El aumento de la urbanización ha contribuido a un incremento en la esperanza de vida.

La gráfica Average Expectancy at Birth and Urban Population by Year muestra la evolución de la esperanza de vida al nacer y la proporción de población urbana entre 1990 y 2020. En el eje X se presenta el tiempo, mientras que en el eje Y se observan los valores promedio de la esperanza de vida y el porcentaje de población urbana. Ambas variables siguen una tendencia creciente similar, lo que sugiere que, a medida que aumenta la población urbana, la esperanza de vida también se incrementa.

En la segunda gráfica Average Expectancy at Birth and Urban Population by Year (2020), se confirma que en los países con una mayor proporción de población urbana, la esperanza de vida al nacer es más alta. El gráfico muestra una línea de tendencia creciente, lo que refuerza la idea de que el crecimiento de la población urbana está relacionado con una mayor esperanza de vida.

Este fenómeno puede explicarse por varios factores asociados a la urbanización. Las ciudades ofrecen un mejor acceso a servicios de salud, infraestructura moderna, educación y condiciones de vida más seguras. Además, en áreas urbanas se dispone de tecnología médica avanzada, lo que facilita la atención y tratamiento de enfermedades, reduciendo la mortalidad y aumentando la esperanza de vida. Este proceso ha tenido un impacto especialmente positivo en la reducción de enfermedades infecciosas y en la mejora de la atención a enfermedades crónicas.
